# %% [markdown]
# # EBook to Text - PDF

# %%
#!pip install ebooklib
# Out:
# Collecting ebooklib
#   Downloading EbookLib-0.17.1.tar.gz (111 kB)
# Requirement already satisfied: lxml in c:\users\aleja\anaconda3\lib\site-packages (from ebooklib) (4.5.0)
# Requirement already satisfied: six in c:\users\aleja\anaconda3\lib\site-packages (from ebooklib) (1.14.0)
# Building wheels for collected packages: ebooklib
#   Building wheel for ebooklib (setup.py): started
#   Building wheel for ebooklib (setup.py): finished with status 'done'
#   Created wheel for ebooklib: filename=EbookLib-0.17.1-py3-none-any.whl size=38167 sha256=8836a57918e97304672e9b90a5b886928d83b03fe13711d2b45229e2bba1fb70
#   Stored in directory: c:\users\aleja\appdata\local\pip\cache\wheels\43\39\fd\db4f652431a55d28472ba7f5f7c9a8efad03b97f443a48ea2f
# Successfully built ebooklib
# Installing collected packages: ebooklib
# Successfully installed ebooklib-0.17.1

# %%
#!pip install BeautifulSoup4
# Out:
# Requirement already satisfied: BeautifulSoup4 in c:\users\aleja\anaconda3\lib\site-packages (4.8.2)
# Requirement already satisfied: soupsieve>=1.2 in c:\users\aleja\anaconda3\lib\site-packages (from BeautifulSoup4) (1.9.5)

# %%
#!pip install pypdf2
# !pip install tika
# Out:
# Collecting tika
#   Downloading tika-1.24.tar.gz (28 kB)
# Requirement already satisfied: setuptools in c:\users\aleja\anaconda3\lib\site-packages (from tika) (45.2.0.post20200210)
# Requirement already satisfied: requests in c:\users\aleja\anaconda3\lib\site-packages (from tika) (2.22.0)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\aleja\anaconda3\lib\site-packages (from requests->tika) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\aleja\anaconda3\lib\site-packages (from requests->tika) (2019.11.28)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\aleja\anaconda3\lib\site-packages (from requests->tika) (2.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\aleja\anaconda3\lib\site-packages (from requests->tika) (1.25.8)
# Building wheels for collected packages: tika
#   Building wheel for tika (setup.py): started
#   Building wheel for tika (setup.py): finished with status 'done'
#   Created wheel for tika: filename=tika-1.24-py3-none-any.whl size=32888 sha256=5ceef25d4b31568aed461c0f1b0473b2deb5ced43cc7d507a65b56a29a788651
#   Stored in directory: c:\users\aleja\appdata\local\pip\cache\wheels\ec\2b\38\58ff05467a742e32f67f5d0de048fa046e764e2fbb25ac93f3
# Successfully built tika
# Installing collected packages: tika
# Successfully installed tika-1.24

# %% [markdown]
# import ebooklib
# from ebooklib import epub
# #epub_path="C:\Users\aleja\OneDrive\Documents\MBA\99. Project Work\Libros\Coelho, Paulo - The Alchemist (0) - libgen.lc.epub"
#
# def epub2thtml(epub_path):
#     book = epub.read_epub(epub_path)
#     chapters = []
#     for item in book.get_items():
#         if item.get_type() == ebooklib.ITEM_DOCUMENT:
#             chapters.append(item.get_content())
#     return chapters

# %% [markdown]
# from bs4 import BeautifulSoup

# %%
import PyPDF2 as pdf
from tika import parser

# %%
#blacklist = [   '[document]',   'noscript', 'header',   'html', 'meta', 'head','input', 'script',   ]
# there may be more elements you don't want, such as "style", etc.

# %% [markdown]
# def chap2text(chap):
#     output = ''
#     soup = BeautifulSoup(chap, 'html.parser')
#     text = soup.find_all(text=True)
#     for t in text:
#         if t.parent.name not in blacklist:
#             output += '{} '.format(t)
#     return output

# %% [markdown]
# def thtml2ttext(thtml):
#     Output = []
#     for html in thtml:
#         text =  chap2text(html)
#         Output.append(text)
#     return Output

# %% [markdown]
# def epub2text(epub_path):
#     chapters = epub2thtml(epub_path)
#     ttext = thtml2ttext(chapters)
#     return ttext

# %%
#pdf_imported=open("C:\\Users\\aleja\\OneDrive\\Documents\\MBA\\99. Project Work\\Libros\\ernst0cheguavara_m0t0rcycled1ar1es.pdf", 'rb')
# !pip install cython
# !pip install git
#!pip install git+git://github.com/kivy/pyjnius.git
# Out:
# Requirement already satisfied: cython in c:\users\aleja\anaconda3\lib\site-packages (0.29.15)
# ERROR: Could not find a version that satisfies the requirement git (from versions: none)
# ERROR: No matching distribution found for git

# %%
#Book="C:\Users\aleja\OneDrive\Documents\MBA\99. Project Work\Libros\Coelho, Paulo - The Alchemist (0) - libgen.lc.epub"
import os
os.environ['CLASSPATH'] = "C:\Users\aleja\OneDrive\Documents\MBA\99. Project Work\Extract-locations-form-a-text-using-NLP--master\tika-app-1.24.1.jar"
# !pip install pyjnius
from jnius import autoclass
#from tika import parser
# Out:
#   File "<ipython-input-39-ca697bb2d3e3>", line 3
#     os.environ['CLASSPATH'] = "C:\Users\aleja\OneDrive\Documents\MBA\99. Project Work\Extract-locations-form-a-text-using-NLP--master\tika-app-1.24.1.jar"
#                              ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
def extract_text(file):
    parsed = parser.from_file(file)
    parsed_text = parsed['content']
    parsed_text = parsed_text.lower()
    return parsed_text

File="C:\\Users\\aleja\\OneDrive\\Documents\\MBA\\99. Project Work\\Libros\\ernst0cheguavara_m0t0rcycled1ar1es.pdf"
#raw = parser.from_file(File)
#print(raw['content'])
#file_name_with_extension = input("Enter File Name:")
text = extract_text(File)
print(text)
#out=epub2text('Coelho, Paulo - The Alchemist (0) - libgen.lc.epub')

#pdf_reader=pdf.PdfFileReader(pdf_imported)
#paginas=pdf_reader.numPages
#print(paginas)

# %%
page=pdf_reader.getPage(50)

# %%
text=page.extractText()
text
# Out:
# ''

# %%
import spacy
import spacy.displacy as displacy #Text Visualization

# %%
nlp=spacy.load("en_core_web_lg")

# %%
doc3=nlp(doc)

# %%
type(out)
# Out:
# list

# %%
out[4][10]
# Out:
# 'e'

# %%
def listToString(s):  
    
    # initialize an empty string 
    str1 = " " 
    
    # return string   
    return (str1.join(s)) 
        
        
# Driver code     
Book=(listToString(out))

# %%
Book2=nlp(Book)

# %%
lugares=[]
for ent in Book2.ents:
    print(ent.text, ent.label_)
    if ent.label_=="GPE" or  ent.label_=="LOC" or  ent.label_=="FAC":
        lugares.append(ent.text)
# Out:
# Paulo Coelho PERSON
# Alan R. Clarke PERSON
# 1992 DATE
# ISBN ORG
# ONE CARDINAL
# Santiago GPE
# Dusk TIME
# the night TIME
# the night TIME
# the night TIME
# the entire next day DATE
# half CARDINAL
# that night TIME
# a week ago DATE
# the past two years DATE
# one CARDINAL
# one CARDINAL
# the past few days DATE
# about only one CARDINAL
# about four days DATE
# the year before DATE
# the afternoon TIME
# Andalusia GPE
# Moorish NORP
# the two hours TIME
# each day DATE
# Andalusian NORP
# one CARDINAL
# Moorish NORP
# the day DATE
# three days DATE
# one CARDINAL
# four CARDINAL
# the following year DATE
# only four days DATE
# The day DATE
# Andalusia GPE
# their days DATE
# today DATE
# one CARDINAL
# one CARDINAL
# second ORDINAL
# night TIME
# a few hours TIME
# Spain GPE
# the summer DATE
# two years DATE
# Andalusian NORP
# sixteen DATE
# Latin LANGUAGE
# Spanish LANGUAGE
# One afternoon TIME
# The next day DATE
# three CARDINAL
# Spanish NORP
# one day DATE
# dozens of years DATE
# every night TIME
# several days DATE
# every day DATE
# Andalusian NORP
# Tarifa GPE
# midday TIME
# Tarifa GPE
# two CARDINAL
# Gypsy PERSON
# Gypsies PERSON
# Egyptian NORP
# Egyptian NORP
# Egyptian NORP
# three CARDINAL
# one-tenth CARDINAL
# First ORDINAL
# one-tenth CARDINAL
# Pyramids NORP
# Egypt GPE
# Egypt GPE
# Egypt GPE
# first ORDINAL
# one CARDINAL
# The day DATE
# every day DATE
# Three days from now DATE
# first ORDINAL
# one CARDINAL
# a snowy day DATE
# two CARDINAL
# first ORDINAL
# second ORDINAL
# Arab NORP
# Africa LOC
# only a few hours TIME
# Tarifa GPE
# one CARDINAL
# Arabs NORP
# one CARDINAL
# Salem GPE
# Salem GPE
# Salem GPE
# Salem GPE
# Andalusia GPE
# Salem GPE
# Salem GPE
# Salem GPE
# Melchizedek PERSON
# one-tenth CARDINAL
# Salem GPE
# earth LOC
# The Soul of the World WORK_OF_ART
# first ORDINAL
# baker PERSON
# one CARDINAL
# first ORDINAL
# a month DATE
# Africa LOC
# one CARDINAL
# the week before DATE
# five years DATE
# hundreds of thousands CARDINAL
# one CARDINAL
# one CARDINAL
# five fruitless years DATE
# Treasure WORK_OF_ART
# one-tenth CARDINAL
# about one-tenth CARDINAL
# one-tenth CARDINAL
# the Warriors of the Light ORG
# Tomorrow DATE
# a tenth CARDINAL
# afternoon TIME
# baker PERSON
# baker PERSON
# three days DATE
# Africa LOC
# Egypt GPE
# Africa LOC
# tomorrow DATE
# just one CARDINAL
# two years DATE
# Andalusia GPE
# Africa LOC
# Moors LOC
# Spain GPE
# two months from now DATE
# Levant GPE
# Mediterranean LOC
# which day DATE
# each day DATE
# every day DATE
# baker PERSON
# levanter PERSON
# Moors ORG
# Pyramids NORP
# Andalusia GPE
# The next day DATE
# noon TIME
# six CARDINAL
# first ORDINAL
# Egypt GPE
# Pyramids LOC
# four CARDINAL
# the previous day DATE
# Urim and ORG
# Thummim PERSON
# Pyramids NORP
# six CARDINAL
# only one CARDINAL
# forty days DATE
# two hours TIME
# two hours TIME
# two CARDINAL
# two hours TIME
# Persian NORP
# ten years DATE
# only one CARDINAL
# Tarifa GPE
# Africa LOC
# Melchizedek PERSON
# Salem GPE
# Melchizedek PERSON
# Abraham PERSON
# one-tenth CARDINAL
# Salem GPE
# Melchizedek PERSON
# Salem GPE
# Africa LOC
# Tangier GPE
# just a few hours TIME
# Saint Santiago Matamoros GPE
# Arabic LANGUAGE
# Pyramids LOC
# six CARDINAL
# Andalusia GPE
# Spanish LANGUAGE
# Spanish LANGUAGE
# Spanish LANGUAGE
# only two hours TIME
# Spain GPE
# Pyramids NORP
# Arab NORP
# Sahara LOC
# two CARDINAL
# Arabic LANGUAGE
# Tangier PERSON
# Africa LOC
# Pyramids NORP
# tomorrow DATE
# two CARDINAL
# Tangier GPE
# thousands CARDINAL
# Egypt GPE
# sixty CARDINAL
# one CARDINAL
# two CARDINAL
# six CARDINAL
# two CARDINAL
# the night TIME
# Urim and ORG
# Thummim PERSON
# Urim ORG
# Thummim PERSON
# two CARDINAL
# Pyramids ORG
# just two hours TIME
# the night TIME
# day DATE
# first ORDINAL
# the day DATE
# one CARDINAL
# Arabic LANGUAGE
# Spanish LANGUAGE
# Tangier GPE
# the day DATE
# every morning TIME
# thirty years DATE
# Arab NORP
# French NORP
# English LANGUAGE
# German NORP
# those days DATE
# Tangier ORG
# Ceuta GPE
# Tangier ORG
# thirty years DATE
# the entire morning TIME
# years DATE
# a few minutes TIME
# half an hour TIME
# two CARDINAL
# Koran PERSON
# Two CARDINAL
# today DATE
# so many years DATE
# today DATE
# all night TIME
# Egypt GPE
# tomorrow DATE
# an entire year DATE
# Egypt GPE
# thousands of kilometers QUANTITY
# TWO CARDINAL
# almost a month DATE
# the entire day DATE
# That morning TIME
# one CARDINAL
# three CARDINAL
# the old days DATE
# one CARDINAL
# Tangier ORG
# Pyramids ORG
# Pyramids NORP
# Two days later DATE
# Hassan PERSON
# two CARDINAL
# Prophet PERSON
# Koran PERSON
# just five CARDINAL
# five CARDINAL
# Ramadan DATE
# Prophet PERSON
# Muslim NORP
# fifth ORDINAL
# Two days ago DATE
# fifth ORDINAL
# Muslim NORP
# Mecca GPE
# Mecca GPE
# Pyramids NORP
# Mecca GPE
# Mecca GPE
# One CARDINAL
# almost a year DATE
# Tangier ORG
# Mecca GPE
# Mecca GPE
# these days DATE
# Pyramids NORP
# Mecca GPE
# thousand CARDINAL
# the Plaza of the Sacred Stone FAC
# seven CARDINAL
# That day DATE
# Two more months DATE
# six more months DATE
# Spain GPE
# sixty CARDINAL
# less than a year DATE
# Arabs NORP
# that morning TIME
# Urim and ORG
# Thummim PERSON
# Egypt GPE
# Mecca GPE
# Tarifa GPE
# One afternoon TIME
# afternoon TIME
# Arabs NORP
# thirty years DATE
# Today DATE
# baker PERSON
# Tarifa GPE
# Arabic LANGUAGE
# Arabic LANGUAGE
# Maktub PERSON
# Arab NORP
# third ORDINAL
# Orient LOC
# two CARDINAL
# the months DATE
# eleven months and nine days DATE
# first ORDINAL
# African NORP
# Arabian NORP
# this day DATE
# a hundred and twenty QUANTITY
# Africa LOC
# two CARDINAL
# today DATE
# Mecca GPE
# Mecca GPE
# Maktub PERSON
# three CARDINAL
# two CARDINAL
# Urim ORG
# Thummim PERSON
# nearly a year DATE
# Spain GPE
# Urim ORG
# Thummim PERSON
# a year DATE
# Arabic LANGUAGE
# Tangier PERSON
# Pyramids NORP
# one CARDINAL
# two CARDINAL
# first ORDINAL
# his first day DATE
# Tangier GPE
# an entire year DATE
# minute TIME
# Mecca GPE
# Urim PERSON
# Thummim PERSON
# Pyramids NORP
# Egypt GPE
# Andalusia GPE
# only two hours TIME
# Pyramids NORP
# two hours TIME
# the two hours TIME
# an entire year DATE
# one CARDINAL
# Urim ORG
# two thousand CARDINAL
# Al-Fayoum GPE
# five hundred CARDINAL
# Al-Fayoum GPE
# half an hour TIME
# afternoon TIME
# Tradition ORG
# Tradition ORG
# fifty CARDINAL
# Joseph PERSON
# Egypt GPE
# first ORDINAL
# Arabs NORP
# two CARDINAL
# the day before DATE
# Englishman NORP
# first ORDINAL
# fifty CARDINAL
# Pyramids NORP
# Fatima PERSON
# Pyramids NORP
# tonight TIME
# Tomorrow DATE
# thousands CARDINAL
# The following night TIME
# almost half an hour TIME
# minutes TIME
# two hundred years old DATE
# Pyramids NORP
# Pyramids NORP
# the previous night TIME
# Fatima PERSON
# Fatima PERSON
# Fatima PERSON
# Fatima PERSON
# a year DATE
# fifty thousand CARDINAL
# the second year DATE
# the third year DATE
# around, night after night TIME
# Fatima PERSON
# Fatima PERSON
# the fourth year DATE
# Mecca GPE
# Fatima PERSON
# tomorrow DATE
# a sleepless night TIME
# Two hours before dawn TIME
# Fatima PERSON
# Fatima PERSON
# Arab NORP
# Arab NORP
# Arab NORP
# Fatima PERSON
# two CARDINAL
# Tradition ORG
# Fatima PERSON
# two CARDINAL
# first ORDINAL
# Fatima PERSON
# one day DATE
# Fatima PERSON
# Fatima PERSON
# years DATE
# fifty thousand CARDINAL
# three hundred CARDINAL
# that day DATE
# that day DATE
# that day DATE
# only one CARDINAL
# the Soul of the World WORK_OF_ART
# Fatima PERSON
# the first day DATE
# second ORDINAL
# two CARDINAL
# night TIME
# a week DATE
# the seventh day DATE
# only one CARDINAL
# only one CARDINAL
# the Master Work WORK_OF_ART
# the Emerald Tablet ORG
# today DATE
# the Emerald Tablet WORK_OF_ART
# less than five minutes TIME
# that day DATE
# years DATE
# years ago DATE
# the Emerald Tablet ORG
# Englishman NORP
# two CARDINAL
# The Emerald Tablet ORG
# the Soul of the World WORK_OF_ART
# the Emerald Tablet ORG
# the Emerald Tablet ORG
# the Soul of the World WORK_OF_ART
# one day DATE
# another two days DATE
# hours TIME
# that day DATE
# the next three days DATE
# two CARDINAL
# the Soul of the World WORK_OF_ART
# one afternoon TIME
# one night TIME
# second ORDINAL
# second ORDINAL
# second ORDINAL
# every hour TIME
# an entire afternoon TIME
# the Soul of the World WORK_OF_ART
# millions of years DATE
# the Soul of the World WORK_OF_ART
# Pyramids NORP
# one CARDINAL
# the Soul of the World WORK_OF_ART
# the darkest hour of the night TIME
# the following day DATE
# first ORDINAL
# Three CARDINAL
# one CARDINAL
# tribesman NORP
# Pyramids NORP
# Arabs NORP
# one CARDINAL
# every day DATE
# the Soul of the World WORK_OF_ART
# one CARDINAL
# the day DATE
# two CARDINAL
# One afternoon TIME
# one CARDINAL
# Arabs NORP
# two CARDINAL
# one CARDINAL
# the Soul of the World WORK_OF_ART
# two CARDINAL
# one CARDINAL
# two CARDINAL
# only two days DATE
# Pyramids ORG
# Tradition ORG
# the Philosopher's Stone WORK_OF_ART
# Pyramids NORP
# Egypt GPE
# Five minutes later TIME
# two CARDINAL
# two CARDINAL
# ten CARDINAL
# a hundred CARDINAL
# two CARDINAL
# one CARDINAL
# three days ago DATE
# Arab NORP
# three days DATE
# three days DATE
# Arabs NORP
# t6 PRODUCT
# three days DATE
# only one CARDINAL
# like millions CARDINAL
# The first day DATE
# one CARDINAL
# the end of the day DATE
# the second day DATE
# the entire afternoon of the second day TIME
# the third day DATE
# the previous day DATE
# so many months DATE
# Englishman NORP
# fifty thousand CARDINAL
# three hundred CARDINAL
# today DATE
# yesterday DATE
# Love WORK_OF_ART
# years DATE
# one day DATE
# first ORDINAL
# earth LOC
# a few moments TIME
# One day DATE
# east LOC
# Moorish NORP
# Andalusia GPE
# two CARDINAL
# two CARDINAL
# the Soul of the World WORK_OF_ART
# the Soul of the World WORK_OF_ART
# the fifth day DATE
# a sixth day DATE
# a sixth day DATE
# one day DATE
# the Soul of the World WORK_OF_ART
# one CARDINAL
# the Soul of the World WORK_OF_ART
# first ORDINAL
# the Soul of the World WORK_OF_ART
# a minute TIME
# earth LOC
# earth LOC
# six days DATE
# a Master Work WORK_OF_ART
# the Soul of the World WORK_OF_ART
# the Soul of God WORK_OF_ART
# that day DATE
# Arabs NORP
# two CARDINAL
# The following day DATE
# the entire day DATE
# the end of the afternoon DATE
# Coptic NORP
# only three hours TIME
# Pyramids NORP
# a few minutes TIME
# Coptic NORP
# Giza GPE
# four CARDINAL
# one CARDINAL
# fourth ORDINAL
# Arab NORP
# third ORDINAL
# Rome GPE
# Tiberius PERSON
# two CARDINAL
# One CARDINAL
# Rome GPE
# One night TIME
# one CARDINAL
# 'Life was good to me,' the man said. WORK_OF_ART
# thousands CARDINAL
# Rome GPE
# Tiberius ORG
# One afternoon TIME
# one CARDINAL
# days DATE
# days DATE
# Roman NORP
# several hours TIME
# two CARDINAL
# a month DATE
# the day DATE
# Pyramids LOC
# Egypt GPE
# Englishman NORP
# Fatima PERSON
# Egypt GPE
# the night TIME
# the centuries DATE
# Pyramids NORP
# one CARDINAL
# Arab NORP
# Pyramids NORP
# Egypt GPE
# one CARDINAL
# Two years ago DATE
# Spain GPE
# Pyramids NORP
# just as night TIME
# half CARDINAL
# a peaceful night TIME
# the night TIME
# Gypsy PERSON
# Pyramids NORP
# Half an hour later TIME
# An hour later TIME
# Spanish NORP
# Urim PERSON
# Thummim PERSON
# two CARDINAL
# one morning TIME
# Urim ORG
# Thummim PERSON
# Tarifa GPE
# one-tenth CARDINAL
# Africa LOC
# Moorish NORP
# first ORDINAL
# Fatima PERSON

# %%
lugares
# Out:
# ['Santiago',
#  'Andalusia',
#  'Andalusia',
#  'Spain',
#  'Tarifa',
#  'Tarifa',
#  'Egypt',
#  'Egypt',
#  'Egypt',
#  'Africa',
#  'Tarifa',
#  'Salem',
#  'Salem',
#  'Salem',
#  'Salem',
#  'Andalusia',
#  'Salem',
#  'Salem',
#  'Salem',
#  'Salem',
#  'earth',
#  'Africa',
#  'Africa',
#  'Egypt',
#  'Africa',
#  'Andalusia',
#  'Africa',
#  'Moors',
#  'Spain',
#  'Levant',
#  'Mediterranean',
#  'Andalusia',
#  'Egypt',
#  'Pyramids',
#  'Tarifa',
#  'Africa',
#  'Salem',
#  'Salem',
#  'Salem',
#  'Africa',
#  'Tangier',
#  'Saint Santiago Matamoros',
#  'Pyramids',
#  'Andalusia',
#  'Spain',
#  'Sahara',
#  'Africa',
#  'Tangier',
#  'Egypt',
#  'Tangier',
#  'Ceuta',
#  'Egypt',
#  'Egypt',
#  'Mecca',
#  'Mecca',
#  'Mecca',
#  'Mecca',
#  'Mecca',
#  'Mecca',
#  'Mecca',
#  'the Plaza of the Sacred Stone',
#  'Spain',
#  'Egypt',
#  'Mecca',
#  'Tarifa',
#  'Tarifa',
#  'Orient',
#  'Africa',
#  'Mecca',
#  'Mecca',
#  'Spain',
#  'Tangier',
#  'Mecca',
#  'Egypt',
#  'Andalusia',
#  'Europe',
#  'the Al-Fayoum oasis',
#  'Sahara',
#  'Al-Fayoum',
#  'earth',
#  'Egypt',
#  'Egypt',
#  'Africa',
#  'Tarifa',
#  'Andalusia',
#  'El Cairum',
#  'Mecca',
#  'Nile',
#  'Spain',
#  'Tarifa',
#  'earth',
#  'Egypt',
#  'Egypt',
#  'Egypt',
#  'Santiago Matamoros',
#  'Al-Fayoum',
#  'Al-Fayoum',
#  'Egypt',
#  'Mecca',
#  'Egypt',
#  'earth',
#  'east',
#  'Andalusia',
#  'earth',
#  'earth',
#  'Giza',
#  'Rome',
#  'Rome',
#  'Rome',
#  'Pyramids',
#  'Egypt',
#  'Egypt',
#  'Egypt',
#  'Spain',
#  'Tarifa',
#  'Africa']

# %%
displacy.serve(Book2, style="ent")
# Out:
# C:\Users\aleja\anaconda3\lib\site-packages\spacy\displacy\__init__.py:94: UserWarning: [W011] It looks like you're calling displacy.serve from within a Jupyter notebook or a similar environment. This likely means you're already running a local web server, so there's no need to make displaCy start another one. Instead, you should be able to replace displacy.serve with displacy.render to show the visualization.
#   warnings.warn(Warnings.W011)
# <span class="tex2jax_ignore"><!DOCTYPE html>
# <html lang="en">
#     <head>
#         <title>displaCy</title>
#     </head>
#
#     <body style="font-size: 16px; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Helvetica, Arial, sans-serif, 'Apple Color Emoji', 'Segoe UI Emoji', 'Segoe UI Symbol'; padding: 4rem 2rem; direction: ltr">
# <figure style="margin-bottom: 6rem">
# <div class="entities" style="line-height: 2.5; direction: ltr"></br> The Alchemist </br> </br> </br> The Alchemist </br>
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Paulo Coelho
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  </br> Translated by
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Alan R. Clarke
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# . Published
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1992
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# .
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ISBN
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  0-7225-3293-8. </br> PART
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ONE
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  </br> The boy's name was
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Santiago
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# .
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Dusk
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
#  was falling as the boy arrived with his herd at an abandoned church. The roof had fallen in long ago, and an enormous sycamore had grown on the spot where the sacristy had once stood. </br> He decided to spend
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the night
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
#  there. He saw to it that all the sheep entered through the ruined gate, and then laid some planks across it to prevent the flock from wandering away during
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the night
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
# . There were no wolves in the region, but once an animal had strayed during
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the night
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
# , and the boy had had to spend
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the entire next day
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  searching for it. </br> He swept the floor with his jacket and lay down, using the book he had just finished reading as a pillow. He told himself that he would have to start reading thicker books: they lasted longer, and made more comfortable pillows. </br> It was still dark when he awoke, and, looking up, he could see the stars through the
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     half
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# -destroyed roof. </br> I wanted to sleep a little longer, he thought. He had had the same dream
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     that night
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
#  as
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     a week ago
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , and once again he had awakened before it ended. </br> He arose and, taking up his crook, began to awaken the sheep that still slept. He had noticed that, as soon as he awoke, most of his animals also began to stir. It was as if some mysterious energy bound his life to that of the sheep, with whom he had spent
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the past two years
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , leading them through the countryside in search of food and water. “They are so used to me that they know my schedule,” he muttered. Thinking about that for a moment, he realized that it could be the other way around: that it was he who had become accustomed to their schedule. </br> But there were certain of them who took a bit longer to awaken. The boy prodded them,
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     one
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  by
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     one
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# , with his crook, calling each by name. He had always believed that the sheep were able to understand what he said. So there were times when he read them parts of his books
# Using the 'ent' visualizer
# Serving on http://0.0.0.0:5000 ...
#
# Shutting down server on port 5000.

# %%
import numpy as np  # useful for many scientific computing in Python
import pandas as pd # primary data structure library

# %%
np.save('lugares_Alchimist', lugares)
