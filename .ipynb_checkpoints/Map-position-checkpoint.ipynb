# %%
import numpy as np
import pandas as pd

# %%
#!conda install -c conda-forge folium=0.5.0 --yes

# %%
import folium

# %%
# define the world map
world_map = folium.Map()

# display world map
world_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [raw]
# Then, use the folium.Map function to initialise a map. Several tiles are available:
#
# OpenStreetMap,
# Stamen Terrain,
# Stamen Toner,
# Mapbox Bright, xxxxxxxxxx
# Mapbox Control Room. xxxxxxxxxxxxxxxx
#
# Note that the tile you need probably depends on the zoom you want to apply to your map. Here are a few example, with 2 different degree of zoom.

# %%
# define the world map centered around Canada with a low zoom level
world_map = folium.Map(location=[10, -66], zoom_start=8, tiles='OpenStreetMap')

# display world map
world_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
lugares2=np.load('lugares_Diarios.npy')
#lugares2=np.load('lugares_Alchemist.npy')

# %%
lugares2
# Out:
# array(['America', 'El Che', 'South America', 'Latin America',
#        'the  Andes  ', 'Latin America', 'Cuba', 'Ocean Sur', 'Australia',
#        'North Melbourne', 'Australia', 'United States', 'Canada',
#        'Australia', 'New Zealand', 'Cuba', 'Latin America', 'Ocean Sur',
#        'San Martín de los Andes', 'Lakes Road', 'Chile', 'Chile',
#        'Pachamama', 'Peru', 'San Pablo', 'Saint Guevara', 'Caracas',
#        'Argentina', 'Latin America', 'Latin America', 'Havana',
#        'Latin America', 'Buenos Aires', 'Atlantic', 'Argentina', 'Chile',
#        'Chile', 'Peru', 'Colombia', 'Caracas', 'Latin America', 'America',
#        'Cuba', 'Havana', 'Cuba', 'Rosario', 'Argentina', 'Latin America',
#        'Guatemala', 'Mexico', 'Guatemala', 'Argentina', 'Cuba', 'Cuba',
#        'Sierra Maestra', 'the Sierra Maestra', 'Cuba', 'Asia', 'Africa',
#        'Latin America', 'Uruguay', 'U.S.', 'Cuba', 'Congo', 'Cuba',
#        'Bolivia', 'Bolivia', 'Cuba', 'Cuba', 'Rosario', 'Argentina',
#        'Buenos Aires', 'Alta Gracia', 'Córdoba', 'Argentina',
#        'North America', 'Córdoba', 'Buenos Aires', 'Latin America',
#        'Bolivia', 'Peru', 'Ecuador', 'Panama', 'Guatemala', 'Bolivia',
#        'Guatemala', 'Mexico', 'Mexico', 'Santa Clara', 'Cuba', 'Cuba',
#        'the Soviet Union', 'Czechoslovakia', 'China', 'Cuba', 'Uruguay',
#        'U.S.', 'the Soviet Union', 'Algeria', 'France', 'Africa', 'Cuba',
#        'Bolivia', 'Bolivia', 'Washington', 'Cuba', 'Bolivia', 'Cuba',
#        'Santa Clara', 'ARGENTINA', 'Córdoba', 'Buenos Aires',
#        'Buenos Aires', 'Miramar', 'San Martín de los Andes',
#        'Nahuel Huapí', 'San Carlos de Bariloche', 'CHILE', 'Los Ángeles',
#        'Santiago de Chile', 'San Antonio', 'Antofagasta', 'Iquique',
#        'Toco', 'La Rica Aventura', 'Arica', 'PERU', 'Tacna',
#        'Lake Titicaca', 'Cuzco', 'Machu Picchu', 'Ayacucho', 'La Merced',
#        'Lima', 'Cerro de Pasco', 'pa', 'Iquitos', 'San Pablo',
#        'San Pablo', 'Bogotá', 'VENEZUELA', 'Caracas', 'Miami',
#        'ARGENTINA', 'Córdoba', 'Latin America', 'Latin America',
#        'North America', 'North America', 'North America', 'Caracas',
#        'Miramar', 'Mar Verde', 'al otted', 'Andes', 'Caracas', 'Spain',
#        'Antofagasta', 'Chile', 'the   San Antonio ]', 'al  ', 'Baquedano',
#        'Cuba', 'Cuba', 'Cuba', 'Cuba', 'Chile', 'Argentina', 'Chile',
#        'Peru', 'Pachamama', 'Mother Earth', 'Cuzco', 'South America',
#        'Cuzco', 'Lima', 'Lima', 'Cuzco', 'Panama', 'Panama', 'Americas',
#        'San Pablo', 'Mexico', 'Straits', 'Peru', 'a United Latin America',
#        'Bogotá', 'San Pablo', 'Caracas', 'America', 'Spain',
#        'Latin America', 'U.S.', 'cit .', 'Spain', 'Argentina', 'Chile',
#        'Peru', 'Havana', 'Casa de las Américas', 'Córdoba',
#        'San Francisco del Chañar', 'the Español Hospital', 'Asia',
#        'North America', 'North America', 'Chile', 'Argentina', 'Atlantic',
#        'earth', 'Mar del Plata', 'Bariloche', 'Miramar', 'Miramar',
#        'Miramar', 'America', 'Necochea', 'Mar del Plata', 'Bahía Blanca',
#        'Médanos', 'al  ', 'especial y', 'San Martín de los Andes',
#        'Argentina', 'San Martín de los Andes', 'san martín de los andes',
#        'Andes', 'San Martín', 'Argentina', 'Argentina',
#        'the National Parks', 'Argentina', 'Carrué Chico', 'Carrué Grande',
#        'Chile', 'Bariloche', 'Choele Choel', 'San Martín de los Andes',
#        'the Von Putnamers', 'Bariloche', 'Bariloche', 'La Poderosa’s',
#        'Angostura', 'San Carlos de Bariloche', 'Chile', 'Miramar',
#        'Mexico', 'Esmeralda', 'cal ed Casa Pangue', 'Chile', 'Chile',
#        'Esmeralda', 'Andes', 'Chile', 'Easter Island', 'Chile',
#        'Valparaíso', 'Petrohué', 'Chile', 'Osorno', 'Lake Osorno',
#        'Osorno', 'Osorno', 'Easter Island', 'Chile', 'Chile', 'Santiago',
#        'AMERICA', 'Americas', 'Easter Island', 'Lautaro', 'Americas',
#        'Los Ángeles', 'Argentina', 'Chile', 'Santiago', 'Los Ángeles',
#        'Los Ángeles', 'Santiago', 'Santiago', 'Córdoba', 'Mediterranean',
#        'Peru', 'Córdoba', 'Santiago', 'Santa Lucía', 'Spain', 'Santiago',
#        'Chile', 'the  bay', 'Easter Island', 'Easter  Island',
#        'Valparaíso', 'Petrohué', 'La Gioconda', 'Chile', 'Chile', 'Chile',
#        'the   San Antonio', 'San Antonio', 'Antofagasta', 'Antofagasta',
#        'San Antonio', 'Calama', 'Antofagasta', 'Chile', 'Chile',
#        'Iquique', 'Chile', 'La Victoria', 'Iquique', 'Arica', 'Iquique',
#        'Arica', 'America', 'Rome', 'Chile', 'Arica', 'Peru', 'Pacific',
#        'Tacna', 'Peru', 'CHILE', 'chile', 'Chile', 'Chile',
#        'South  America', 'Chile', 'Argentina', 'Argentina', 'Andes',
#        'the \n \n United States', 'the United States', 'Chile',
#        'especial y', 'Chile', 'EL MUNDO NUEVO', 'Chile', 'Argentina',
#        'Argentina', 'al uring vision', 'Puno', 'Chile', 'Atacarna',
#        'Aymaras', 'Pachamama', 'Earth', 'Pachamama', 'Aymaras',
#        'the bay Puno', 'Puno', 'Bolivia', 'England', 'Cuzco', 'Cuzco',
#        'North America', '‘North America', 'Havana', 'Argentina',
#        'Buenos Aires', 'Argentina', 'Buenos Aires', 'Argentina',
#        'the Argentine Andes', 'San Martín de los Andes',
#        'Modesta Victoria', 'Chile', 'Lake Nahuel Huapí', 'Córdoba',
#        'Santiago de Chile', 'Taratá', 'Puno', 'Peru', 'Cuzco', 'Cuzco',
#        'Cuzco', 'the Temple of the Sun', 'the Temple of the Sun',
#        'the Peruvian Andes', 'Incas', 'Machu Picchu', 'Huayna',
#        'Americas', 'Pucal pa', 'Peru', 'San Pablo', 'San Pablo', 'Yaguas',
#        'the Amazon River', 'Latin America', 'Haiti',
#        'the Dominican Republic', 'Latin America', 'Lima', 'Lima',
#        'Sicuani', 'Cuzco', 'Incas', 'Cuzco', 'Cuzco', 'il', 'Spain',
#        'Cuzco', 'Cuzco', 'Cuzco', 'Cuzco', 'Cuzco', 'America', 'Andes',
#        'Santo Domingo', 'the Temple of the Sun', 'Cuzco',
#        'Urubamba Rivers', 'Incas', 'Cuzco', 'the Vilcanota River',
#        'Cuzco', 'U.S.', 'Machu Picchu', 'the Temple of the Sun',
#        'the Temple of the Sun', 'Huayna', 'Machu Picchu’s',
#        'Machu Picchu', 'Americas', 'Ollanta', 'María Angola',
#        'the Inca Empire', 'Spain', 'the Inca Empire', 'the Pacific coast',
#        'Lima', 'Peru', 'St. Christopher', 'Cuzco', 'earth', 'Americas',
#        'Machu Picchu', 'Buenos Aires', 'Cuzco', 'Argentina', 'U.S.',
#        'Machu Picchu', 'Peru', 'Lima', 'Cuzco', 'Cuzco', 'Peru',
#        'Huancarama', 'Peru', 'Cuzco', 'Cuzco', 'Andahuaylas', 'Lima',
#        'Andahuaylas', 'Lima', 'Peru', 'Ayacucho', 'Lima', 'PERUANO',
#        'peru', 'Huancal', 'Oxapampa', 'Lima', 'San Ramón', 'Lima',
#        'Argentina', 'San Ramón', 'Argentina', 'Lima', 'Lima', 'Lima',
#        'Cal ao', 'al  ports', 'Latin America’s', 'Cuzco', 'Lima', 'Cuzco',
#        'America', 'Lima', 'Peru', 'Machu Picchu', 'Córdoba', 'Cal ao',
#        'North America', 'Peru', 'Buenos', 'Aires', 'Lima', 'Lima',
#        'Cerro de Pasco', 'Ticlio', 'Iquitos', 'the Ucayali River',
#        'the Upper Paraná', 'The Hospital de Guía', 'La Cenepa',
#        'Malagueño', 'Iquitos', 'Iquitos', 'Iquitos', 'Yagua', 'Venezuela',
#        'San Pablo', 'Bogotá', 'Leguisamo', 'Lima', 'Indochina', 'Peru',
#        'Tacna', 'Mexico', 'Peru', 'a United Latin America', 'Yaguas',
#        'Peru', 'Brazil', 'Colombia', 'Venezuela', 'Iquitos', 'Colombia',
#        'Paraguay', 'San Pablo', 'Brazil', 'al', 'Bogotá', 'Atlantic',
#        'Paris', 'the  Atlantic', 'Bogotá', 'Peru', 'Venezuela',
#        'Colombia', 'Bogotá', 'Caracas', 'Venezuela', 'caracas',
#        'San Antonio de Táchira', 'San Cristóbal', 'Bogotá', 'Caracas',
#        'especial y', 'Córdoba', 'Colombia', 'San Cristóbal', 'Caracas',
#        'Colombia', 'the Venezuelan Andes', 'Caracas', 'Caracas',
#        'Caracas', 'America', 'Caracas', 'Caracas', 'North', 'Europe',
#        'Cuba', 'Guatemala', 'Latin America', 'Haiti',
#        'the Dominican Republic', 'Latin America', 'Guatemala',
#        'Guatemala', 'U.S.', 'Guatemala', 'Latin America', 'Cuba', 'Cuba',
#        'Havana', 'Cuba', 'Cuba', 'Cuba', 'Cuba', 'especial y', 'Cuba',
#        'Latin America', 'Africa', 'Asia', 'Cuba', 'Cuba', 'Cuba',
#        'Havana', 'the   Granma', 'the Sierra Maestra', 'Cuba', 'Cuba',
#        'the United States of America', 'Cuba', 'Cuba', 'Cuba', 'CUBA',
#        'Cuba', 'Latin America', 'Bolivia', 'Bolivia', 'Cuba',
#        'Latin America', 'Bolivia', 'Latin America', 'Latin America',
#        'Bolivia', 'Cuba', 'Cuba', 'Latin America', 'Latin America',
#        'Argentina', 'Machu-Picchu', 'Peru', 'Guatemala', 'US', 'Mexico',
#        'San Martín de los Andes', 'Lakes Road', 'Chile', 'Chile',
#        'Pachamama', 'Peru', 'San Pablo', 'Saint Guevara', 'Caracas'],
#       dtype='<U28')

# %%
#pip install -U googlemaps

# %%
import googlemaps

# %%
g_key=googlemaps.Client(key="AIzaSyAJ0DKhauX591z08eBbYxtcVjbFOZLfd2I")

# %%
lugares3=pd.DataFrame(lugares2)

# %%
lugares3
# Out:
#                  0
# 0          America
# 1           El Che
# 2    South America
# 3    Latin America
# 4     the  Andes
# ..             ...
# 615      Pachamama
# 616           Peru
# 617      San Pablo
# 618  Saint Guevara
# 619        Caracas
#
# [620 rows x 1 columns]

# %%
lugares3["LAT"]= None
lugares3["LON"]= None

for i in range(0, len(lugares3), 1):
    geocode_result=g_key.geocode(lugares3.iat[i,0])
    try:
        lat=geocode_result[0]["geometry"]["location"]["lat"]
        lon=geocode_result[0]["geometry"]["location"]["lng"]
        lugares3.iat[i,lugares3.columns.get_loc("LAT")]=lat
        lugares3.iat[i,lugares3.columns.get_loc("LON")]=lon
    except:
        lat=None
        lon=None

# %%
range(0, len(lugares3), 1)
# Out:
# range(0, 620)

# %%
pd.set_option('display.max_rows', None)
lugares3
# Out:
#                                 0      LAT      LON
# 0                         America  37.0902 -95.7129
# 1                          El Che  41.8829 -87.6492
# 2                   South America -8.78319 -55.4915
# 3                   Latin America -4.44204 -61.3269
# 4                    the  Andes   -21.1608 -66.7752
# 5                   Latin America -4.44204 -61.3269
# 504                        Bogotá  4.71099 -74.0721
# 505                     Leguisamo     None     None
# 506                          Lima -12.0464 -77.0428
# 507                     Indochina  14.7145  102.072
# 508                          Peru -9.18997 -75.0152
# 509                         Tacna -18.0066 -70.2463
# 510                        Mexico  23.6345 -102.553
# 511                          Peru -9.18997 -75.0152
# 512        a United Latin America  38.9048  -77.043
# 513                        Yaguas  31.7574 -106.446
# 514                          Peru -9.18997 -75.0152
# 515                        Brazil  -14.235 -51.9253
# 516                      Colombia  4.57087 -74.2973
# 517                     Venezuela  6.42375 -66.5897
# 518                       Iquitos -3.74367 -73.2516
# 519                      Colombia  4.57087 -74.2973
# 520                      Paraguay -23.4425 -58.4438
# 521                     San Pablo  37.9621 -122.346
# 522                        Brazil  -14.235 -51.9253
# 523                            al  32.3182 -86.9023
# 524                        Bogotá  4.71099 -74.0721
# 525                      Atlantic  36.1924 -95.8933
# 526                         Paris  48.8566  2.35222
# 527                 the  Atlantic  33.7908 -84.3973
# 528                        Bogotá  4.71099 -74.0721
# 529                          Peru -9.18997 -75.0152
# 530                     Venezuela  6.42375 -66.5897
# 531                      Colombia  4.57087 -74.2973
# 532                        Bogotá  4.71099 -74.0721
# 533                       Caracas  10.4806 -66.9036
# 534                     Venezuela  6.42375 -66.5897
# 535                       caracas  10.4806 -66.9036
# 536        San Antonio de Táchira  7.81781 -72.4426
# 537                 San Cristóbal   16.737 -92.6376
# 538                        Bogotá  4.71099 -74.0721
# 539                       Caracas  10.4806 -66.9036
# 540                    especial y  39.1299  -94.717
# 541                       Córdoba  37.8882 -4.77938
# 542                      Colombia  4.57087 -74.2973
# 543                 San Cristóbal   16.737 -92.6376
# 544                       Caracas  10.4806 -66.9036
# 545                      Colombia  4.57087 -74.2973
# 546          the Venezuelan Andes  6.42375 -66.5897
# 547                       Caracas  10.4806 -66.9036
# 548                       Caracas  10.4806 -66.9036
# 549                       Caracas  10.4806 -66.9036
# 550                       America  37.0902 -95.7129
# 551                       Caracas  10.4806 -66.9036
# 552                       Caracas  10.4806 -66.9036
# 553                         North  37.2261 -95.7084
# 554                        Europe   54.526  15.2551
# 555                          Cuba  21.5218 -77.7812
# 556                     Guatemala  15.7835 -90.2308
# 557                 Latin America -4.44204 -61.3269
# 558                         Haiti  18.9712 -72.2852
# 559        the Dominican Republic  18.7357 -70.1627
# 560                 Latin America -4.44204 -61.3269
# 561                     Guatemala  15.7835 -90.2308
# 562                     Guatemala  15.7835 -90.2308
# 563                          U.S.  37.0902 -95.7129
# 564                     Guatemala  15.7835 -90.2308
# 565                 Latin America -4.44204 -61.3269
# 566                          Cuba  21.5218 -77.7812
# 567                          Cuba  21.5218 -77.7812
# 568                        Havana  23.1136 -82.3666
# 569                          Cuba  21.5218 -77.7812
# 570                          Cuba  21.5218 -77.7812
# 571                          Cuba  21.5218 -77.7812
# 572                          Cuba  21.5218 -77.7812
# 573                    especial y  39.1299  -94.717
# 574                          Cuba  21.5218 -77.7812
# 575                 Latin America -4.44204 -61.3269
# 576                        Africa -8.78319  34.5085
# 577                          Asia  34.0479   100.62
# 578                          Cuba  21.5218 -77.7812
# 579                          Cuba  21.5218 -77.7812
# 580                          Cuba  21.5218 -77.7812
# 581                        Havana  23.1136 -82.3666
# 582                  the   Granma  23.1409  -82.357
# 583            the Sierra Maestra   20.054 -76.5951
# 584                          Cuba  21.5218 -77.7812
# 585                          Cuba  21.5218 -77.7812
# 586  the United States of America  37.0902 -95.7129
# 587                          Cuba  21.5218 -77.7812
# 588                          Cuba  21.5218 -77.7812
# 589                          Cuba  21.5218 -77.7812
# 590                          CUBA  21.5218 -77.7812
# 591                          Cuba  21.5218 -77.7812
# 592                 Latin America -4.44204 -61.3269
# 593                       Bolivia -16.2902 -63.5887
# 594                       Bolivia -16.2902 -63.5887
# 595                          Cuba  21.5218 -77.7812
# 596                 Latin America -4.44204 -61.3269
# 597                       Bolivia -16.2902 -63.5887
# 598                 Latin America -4.44204 -61.3269
# 599                 Latin America -4.44204 -61.3269
# 600                       Bolivia -16.2902 -63.5887
# 601                          Cuba  21.5218 -77.7812
# 602                          Cuba  21.5218 -77.7812
# 603                 Latin America -4.44204 -61.3269
# 604                 Latin America -4.44204 -61.3269
# 605                     Argentina -38.4161 -63.6167
# 606                  Machu-Picchu -13.1631  -72.545
# 607                          Peru -9.18997 -75.0152
# 608                     Guatemala  15.7835 -90.2308
# 609                            US  37.0902 -95.7129
# 610                        Mexico  23.6345 -102.553
# 611       San Martín de los Andes -40.1572 -71.3524
# 612                    Lakes Road  41.2826 -74.2413
# 613                         Chile -35.6751  -71.543
# 614                         Chile -35.6751  -71.543
# 615                     Pachamama  37.1771 -94.3105
# 616                          Peru -9.18997 -75.0152
# 617                     San Pablo  37.9621 -122.346
# 618                 Saint Guevara     None     None
# 619                       Caracas  10.4806 -66.9036

# %%
print(geocode_result[0])
# Out:
# {'address_components': [{'long_name': 'Caracas', 'short_name': 'CCS', 'types': ['locality', 'political']}, {'long_name': 'Libertador', 'short_name': 'Libertador', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'Capital District', 'short_name': 'Dto. Capital', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'Venezuela', 'short_name': 'VE', 'types': ['country', 'political']}], 'formatted_address': 'Caracas, Capital District, Venezuela', 'geometry': {'bounds': {'northeast': {'lat': 10.5401335, 'lng': -66.71795329999999}, 'southwest': {'lat': 10.39665, 'lng': -67.0627784}}, 'location': {'lat': 10.4805937, 'lng': -66.90360629999999}, 'location_type': 'APPROXIMATE', 'viewport': {'northeast': {'lat': 10.5401335, 'lng': -66.71795329999999}, 'southwest': {'lat': 10.39665, 'lng': -67.0627784}}}, 'place_id': 'ChIJB0iCza1YKowRg4SZCq4u3ZM', 'types': ['locality', 'political']}

# %%
world_map = folium.Map(location=[lugares3["LAT"][0], lugares3["LON"][0]], zoom_start=6, tiles='OpenStreetMap')

# display world map
world_map
len(lugares3)
# Out:
# 620

# %%
# instantiate a feature group for the incidents in the dataframe
Area = folium.Map(location=[lugares3["LAT"][0], lugares3["LON"][0]], zoom_start=2)
Dots = folium.map.FeatureGroup()
ff=len(lugares3)
i=0
# loop through the lugares points
for lat, lng, in zip(lugares3["LAT"][: ff],lugares3["LON"][: ff]):
    if type(lugares3["LAT"][i])!=type(None):
        Dots.add_child(folium.features.CircleMarker([lat, lng], radius=5, color='red', fill=True, fill_color='blue', fill_opacity=0.6))
    i=i+1

# add pop-up text to each marker on the map
latitudes = list(lugares3["LAT"][: ff])
longitudes = list(lugares3["LON"][: ff])
labels = list(lugares3[0][: ff])

for lat, lng, label in zip(latitudes, longitudes, labels):
    if type(lat)!=type(None):
        folium.Marker([lat, lng], popup=label).add_to(Area) 
    
    
Area.add_child(Dots)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
type(None)
# Out:
# NoneType

# %%
from folium import plugins
ff=len(lugares3)
# let's start again with a clean copy of the map of San Francisco
Area = folium.Map(location=[lugares3["LAT"][0], lugares3["LON"][0]], zoom_start=2)
Dots = plugins.MarkerCluster().add_to(Area)

# loop through the dataframe and add each data point to the mark cluster
for lat, lng, label, in zip(lugares3["LAT"][: ff],lugares3["LON"][: ff], lugares3[0][: ff]):
    if type(lat)!=type(None):
        folium.Marker(
        location=[lat, lng],
        icon=None,
        popup=label,
    ).add_to(Dots)

# display map
Area
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
lugares3["LAT"][: 100]
# Out:
# 0     37.0902
# 1     41.8829
# 2    -8.78319
# 3    -4.44204
# 4    -21.1608
# 5    -4.44204
# 6     21.5218
# 7        None
# 8    -25.2744
# 9     28.2164
# 10   -25.2744
# 11    37.0902
# 12    56.1304
# 13   -25.2744
# 14   -40.9006
# 15    21.5218
# 16   -4.44204
# 17       None
# 18   -40.1572
# 19    41.2826
# 20   -35.6751
# 21   -35.6751
# 22    37.1771
# 23   -9.18997
# 24    37.9621
# 25       None
# 26    10.4806
# 27   -38.4161
# 28   -4.44204
# 29   -4.44204
# 30    23.1136
# 31   -4.44204
# 32   -34.6037
# 33    36.1924
# 34   -38.4161
# 35   -35.6751
# 36   -35.6751
# 37   -9.18997
# 38    4.57087
# 39    10.4806
# 40   -4.44204
# 41    37.0902
# 42    21.5218
# 43    23.1136
# 44    21.5218
# 45    40.8309
# 46   -38.4161
# 47   -4.44204
# 48    15.7835
# 49    23.6345
# 50    15.7835
# 51   -38.4161
# 52    21.5218
# 53    21.5218
# 54     20.054
# 55     20.054
# 56    21.5218
# 57    34.0479
# 58   -8.78319
# 59   -4.44204
# 60   -32.5228
# 61    37.0902
# 62    21.5218
# 63   -4.03833
# 64    21.5218
# 65   -16.2902
# 66   -16.2902
# 67    21.5218
# 68    21.5218
# 69    40.8309
# 70   -38.4161
# 71   -34.6037
# 72   -31.6584
# 73    37.8882
# 74   -38.4161
# 75     54.526
# 76    37.8882
# 77   -34.6037
# 78   -4.44204
# 79   -16.2902
# 80   -9.18997
# 81   -1.83124
# 82    8.53798
# 83    15.7835
# 84   -16.2902
# 85    15.7835
# 86    23.6345
# 87    23.6345
# 88    37.3541
# 89    21.5218
# 90    21.5218
# 91    47.5042
# 92       None
# 93    35.8617
# 94    21.5218
# 95   -32.5228
# 96    37.0902
# 97    47.5042
# 98    28.0339
# 99    46.2276
# Name: LAT, dtype: object
